# %%
import pandas as pd

# %% [markdown]
# Lecture 6

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#set Google Drive path
path_gdrive = '/content/drive/MyDrive/ENV716-F23/'

# %%
#df_plant21=pd.read_excel(io="https://mauricioh2.com/eGRID2021.xlsx",sheet_name="PLNT21")

# %%
import os
os.chdir(path_gdrive)

# %%
df_plant21=pd.read_excel(io="eGRID2021_data.xlsx",sheet_name="PLNT21")

# %%
df_plant21.head()
# Out:
#   Plant file sequence number Data Year Plant state abbreviation  \
# 0                     SEQPLT      YEAR                 PSTATABB
# 1                          1      2021                       AK
# 2                          2      2021                       AK
# 3                          3      2021                       AK
# 4                          4      2021                       AK
#
#                          Plant name DOE/EIA ORIS plant or facility code  \
# 0                             PNAME                              ORISPL
# 1  Agrium Kenai Nitrogen Operations                               54452
# 2                          Alakanuk                               57053
# 3               Allison Creek Hydro                               58982
# 4                            Ambler                               60243
#
#   Plant transmission or distribution system owner name  \
# 0                                            OPRNAME
# ...

# %%
df_plant21=pd.read_excel(io="eGRID2021_data.xlsx",sheet_name="PLNT21",skiprows=1)
df_plant21.head()
# Out:
#    SEQPLT  YEAR PSTATABB                             PNAME  ORISPL  \
# 0       1  2021       AK  Agrium Kenai Nitrogen Operations   54452
# 1       2  2021       AK                          Alakanuk   57053
# 2       3  2021       AK               Allison Creek Hydro   58982
# 3       4  2021       AK                            Ambler   60243
# 4       5  2021       AK                            Angoon    7462
#
#                          OPRNAME  OPRCODE                       UTLSRVNM  \
# 0        Homer Electric Assn Inc    19558                  Agrium US Inc
# 1  Alaska Village Elec Coop, Inc      221  Alaska Village Elec Coop, Inc
# 2   Copper Valley Elec Assn, Inc     4329   Copper Valley Elec Assn, Inc
# 3  Alaska Village Elec Coop, Inc      221  Alaska Village Elec Coop, Inc
# 4  Inside Passage Elec Coop, Inc    18963  Inside Passage Elec Coop, Inc
#
#    UTLSRVID            SECTOR  ... PLWIPR PLSOPR PLGTPR PLOFPR PLOPPR PLTNPR  \
# ...

# %%
df_plant21=pd.read_excel(io="eGRID2021_data.xlsx",sheet_name="PLNT21",skiprows=1,keep_default_na=False)

# %%
df_plant21.head()
# Out:
#    SEQPLT  YEAR PSTATABB                             PNAME  ORISPL  \
# 0       1  2021       AK  Agrium Kenai Nitrogen Operations   54452
# 1       2  2021       AK                          Alakanuk   57053
# 2       3  2021       AK               Allison Creek Hydro   58982
# 3       4  2021       AK                            Ambler   60243
# 4       5  2021       AK                            Angoon    7462
#
#                          OPRNAME  OPRCODE                       UTLSRVNM  \
# 0        Homer Electric Assn Inc    19558                  Agrium US Inc
# 1  Alaska Village Elec Coop, Inc      221  Alaska Village Elec Coop, Inc
# 2   Copper Valley Elec Assn, Inc     4329   Copper Valley Elec Assn, Inc
# 3  Alaska Village Elec Coop, Inc      221  Alaska Village Elec Coop, Inc
# 4  Inside Passage Elec Coop, Inc    18963  Inside Passage Elec Coop, Inc
#
#    UTLSRVID            SECTOR  ... PLWIPR PLSOPR PLGTPR PLOFPR PLOPPR PLTNPR  \
# 0       179    Industrial CHP  ...
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df_plant21.head()
# Out:
#    SEQPLT  YEAR PSTATABB                             PNAME  ORISPL  \
# 0       1  2021       AK  Agrium Kenai Nitrogen Operations   54452
# 1       2  2021       AK                          Alakanuk   57053
# 2       3  2021       AK               Allison Creek Hydro   58982
# 3       4  2021       AK                            Ambler   60243
# 4       5  2021       AK                            Angoon    7462
#
#                          OPRNAME  OPRCODE                       UTLSRVNM  \
# 0        Homer Electric Assn Inc    19558                  Agrium US Inc
# 1  Alaska Village Elec Coop, Inc      221  Alaska Village Elec Coop, Inc
# 2   Copper Valley Elec Assn, Inc     4329   Copper Valley Elec Assn, Inc
# 3  Alaska Village Elec Coop, Inc      221  Alaska Village Elec Coop, Inc
# 4  Inside Passage Elec Coop, Inc    18963  Inside Passage Elec Coop, Inc
#
#    UTLSRVID            SECTOR                  BANAME BACODE NERC SUBRGN  \
# ...

# %%
NumRows=len(df_plant21)

# %%
NumRows
# Out:
# 11393

# %%
print("There is a total of ", NumRows, "Plants in eGRID2021")
# Out:
# There is a total of  11393 Plants in eGRID2021

# %%
df_plant21.dtypes
# Out:
# SEQPLT       int64
# YEAR         int64
# PSTATABB    object
# PNAME       object
# ORISPL       int64
#              ...
# PLTNPR      object
# PLTRPR      object
# PLTHPR      object
# PLCYPR      object
# PLCNPR      object
# Length: 141, dtype: object

# %%
df_plant21.columns
# Out:
# Index(['SEQPLT', 'YEAR', 'PSTATABB', 'PNAME', 'ORISPL', 'OPRNAME', 'OPRCODE',
#        'UTLSRVNM', 'UTLSRVID', 'SECTOR',
#        ...
#        'PLWIPR', 'PLSOPR', 'PLGTPR', 'PLOFPR', 'PLOPPR', 'PLTNPR', 'PLTRPR',
#        'PLTHPR', 'PLCYPR', 'PLCNPR'],
#       dtype='object', length=141)

# %%
df_plant21.columns
# Out:
# Index(['SEQPLT', 'YEAR', 'PSTATABB', 'PNAME', 'ORISPL', 'OPRNAME', 'OPRCODE',
#        'UTLSRVNM', 'UTLSRVID', 'SECTOR',
#        ...
#        'PLWIPR', 'PLSOPR', 'PLGTPR', 'PLOFPR', 'PLOPPR', 'PLTNPR', 'PLTRPR',
#        'PLTHPR', 'PLCYPR', 'PLCNPR'],
#       dtype='object', length=141)

# %%
list(df_plant21.columns.values)
# Out:
# ['SEQPLT',
#  'YEAR',
#  'PSTATABB',
#  'PNAME',
#  'ORISPL',
#  'OPRNAME',
#  'OPRCODE',
#  'UTLSRVNM',
#  'UTLSRVID',
#  'SECTOR',
#  'BANAME',
#  'BACODE',
#  'NERC',
#  'SUBRGN',
#  'SRNAME',
#  'ISORTO',
#  'FIPSST',
#  'FIPSCNTY',
#  'CNTYNAME',
#  'LAT',
#  'LON',
#  'CAMDFLAG',
#  'NUMUNT',
#  'NUMGEN',
#  'PLPRMFL',
#  'PLFUELCT',
#  'COALFLAG',
#  'CAPFAC',
#  'NAMEPCAP',
#  'NBFACTOR',
#  'RMBMFLAG',
#  'CHPFLAG',
#  'USETHRMO',
#  'PWRTOHT',
#  'ELCALLOC',
#  'PSFLAG',
#  'PLHTIAN',
#  'PLHTIOZ',
#  'PLHTIANT',
#  'PLHTIOZT',
#  'PLNGENAN',
#  'PLNGENOZ',
#  'PLNOXAN',
#  'PLNOXOZ',
#  'PLSO2AN',
#  'PLCO2AN',
#  'PLCH4AN',
#  'PLN2OAN',
#  'PLCO2EQA',
#  'PLHGAN',
#  'PLNOXRTA',
#  'PLNOXRTO',
#  'PLSO2RTA',
#  'PLCO2RTA',
#  'PLCH4RTA',
#  'PLN2ORTA',
#  'PLC2ERTA',
#  'PLHGRTA',
#  'PLNOXRA',
#  'PLNOXRO',
#  'PLSO2RA',
#  'PLCO2RA',
#  'PLCH4RA',
#  'PLN2ORA',
#  'PLC2ERA',
#  'PLHGRA',
#  'PLNOXCRT',
#  'PLNOXCRO',
#  'PLSO2CRT',
#  'PLCO2CRT',
#  'PLCH4CRT',
# ...

# %%
capacities=df_plant21['NAMEPCAP']

# %%
capacities
# Out:
# 0         12.5
# 1          0.8
# 2          6.5
# 3          1.1
# 4          1.5
#          ...
# 11388    144.0
# 11389     90.0
# 11390     95.0
# 11391    116.0
# 11392    402.3
# Name: NAMEPCAP, Length: 11393, dtype: float64

# %%
Total_Capacity=df_plant21['NAMEPCAP'].sum()
print("The total power generation installed capacity in 2021 was",Total_Capacity,"MW")
# Out:
# The total power generation installed capacity in 2021 was 1258286.0 MW

# %%
df_plant21.PLNGENAN.dtype
# Out:
# dtype('O')

# %%
df_plant21.PLNGENAN=pd.to_numeric(df_plant21.PLNGENAN)

# %%
df_plant21.PLNGENAN.dtype
# Out:
# dtype('float64')

# %% [markdown]
# Now we can sum all the annual generatio

# %%
US_MWh_Generation=df_plant21.PLNGENAN.sum()

# %%
print("In 2021, all plant in the US generated a total of",US_MWh_Generation,"MWh")
# Out:
# In 2021, all plant in the US generated a total of 4120144619.3580003 MWh

# %%
df_plant21.PLFUELCT.unique()
# Out:
# array(['GAS', 'OIL', 'HYDRO', 'COAL', 'OTHF', 'WIND', 'BIOMASS', 'SOLAR',
#        'NUCLEAR', 'GEOTHERMAL', '', 'OFSL'], dtype=object)

# %%
df_solar21=df_plant21[(df_plant21.PLFUELCT=="SOLAR")]

# %%
NumSolarPlants=len(df_solar21)

# %%
df_solar21.PLNGENAN.dtype
# Out:
# dtype('float64')

# %%
US_Solar_MWh=df_solar21.PLNGENAN.sum()

# %%
US_Solar_MWh
# Out:
# 114600023.452

# %%
print("the total solar generation in 2021 was",US_Solar_MWh,"MWh")
# Out:
# the total solar generation in 2021 was 114600023.452 MWh

# %%
df_solar21_NCSC=df_solar21[(df_solar21.PSTATABB=="NC")|(df_solar21.PSTATABB=="SC")]

# %%
NCSC_Solar_MWh_Gen=df_solar21_NCSC.PLNGENAN.sum()

# %%
print("Solar generation in NC and SC in 2021 was",NCSC_Solar_MWh_Gen,"MWh")
# Out:
# Solar generation in NC and SC in 2021 was 12235273.998 MWh

# %%
Proportion_SolarGen_NCSC=NCSC_Solar_MWh_Gen/US_Solar_MWh

# %%
print("The proportion of solar generation in NC and SC was",Proportion_SolarGen_NCSC)
# Out:
# The proportion of solar generation in NC and SC was 0.10676502176393289

# %%
Percentage=Proportion_SolarGen_NCSC*100

# %%
print("NC and SC generated ",Percentage,"% of the US solar generation in 2021")
# Out:
# NC and SC generated  10.676502176393289 % of the US solar generation in 2021

# %% [markdown]
# Lecture 7

# %%
H7_1=pd.pivot_table(df_plant21,values="PNAME",index="PSTATABB",columns="PLFUELCT",aggfunc='count')

# %%
H7_1
# Out:
# PLFUELCT       BIOMASS  COAL    GAS  GEOTHERMAL  HYDRO  NUCLEAR  OFSL   OIL  \
# PSTATABB
# AK        NaN      1.0   5.0   14.0         NaN   33.0      NaN   NaN  90.0
# AL        NaN     12.0   4.0   25.0         NaN   23.0      2.0   NaN   3.0
# AR        NaN      7.0   5.0   18.0         NaN   19.0      1.0   NaN   2.0
# AZ        NaN      3.0   4.0   28.0         NaN   11.0      1.0   NaN   2.0
# CA        1.0     98.0   1.0  337.0        32.0  254.0      1.0   NaN  14.0
# CO        1.0      4.0   6.0   29.0         NaN   49.0      NaN   1.0   9.0
# CT        NaN      7.0   NaN   48.0         NaN   14.0      1.0   NaN  22.0
# DC        NaN      1.0   NaN    3.0         NaN    NaN      NaN   NaN   NaN
# DE        NaN      3.0   1.0    9.0         NaN    NaN      NaN   NaN   4.0
# FL        NaN     35.0   5.0   63.0         NaN    1.0      2.0   NaN   6.0
# GA        NaN     27.0   3.0   30.0         NaN   30.0      2.0   1.0  23.0
# ...

# %%
H7_1.head(10)
# Out:
# PLFUELCT       BIOMASS  COAL    GAS  GEOTHERMAL  HYDRO  NUCLEAR  OFSL   OIL  \
# PSTATABB
# AK        NaN      1.0   5.0   14.0         NaN   33.0      NaN   NaN  90.0
# AL        NaN     12.0   4.0   25.0         NaN   23.0      2.0   NaN   3.0
# AR        NaN      7.0   5.0   18.0         NaN   19.0      1.0   NaN   2.0
# AZ        NaN      3.0   4.0   28.0         NaN   11.0      1.0   NaN   2.0
# CA        1.0     98.0   1.0  337.0        32.0  254.0      1.0   NaN  14.0
# CO        1.0      4.0   6.0   29.0         NaN   49.0      NaN   1.0   9.0
# CT        NaN      7.0   NaN   48.0         NaN   14.0      1.0   NaN  22.0
# DC        NaN      1.0   NaN    3.0         NaN    NaN      NaN   NaN   NaN
# DE        NaN      3.0   1.0    9.0         NaN    NaN      NaN   NaN   4.0
# FL        NaN     35.0   5.0   63.0         NaN    1.0      2.0   NaN   6.0
#
# PLFUELCT  OTHF  SOLAR   WIND
# PSTATABB
# AK         4.0    NaN    4.0
# AL         NaN    7.0    NaN
# ...

# %%
H7_2=pd.pivot_table(df_plant21,index="PSTATABB",values="NAMEPCAP",columns="PLFUELCT",aggfunc='sum',fill_value="")

# %%
H7_2.head()
# Out:
# PLFUELCT      BIOMASS    COAL      GAS GEOTHERMAL    HYDRO NUCLEAR OFSL  \
# PSTATABB
# AK               11.5   210.9   1409.5               509.3
# AL              583.4  7429.3  13105.4              3318.3  5343.9
# AR              297.6  5487.0   7254.7              1350.9  1845.0
# AZ               33.4  3687.6  16649.0              2912.1  4209.6
# CA        2.2  1215.1    62.5  42048.4     2824.0  13810.7  2323.0
#
# PLFUELCT    OIL    OTHF    SOLAR    WIND
# PSTATABB
# AK        803.1    46.0             53.5
# AL         26.6            424.9
# AR          8.8            235.7
# AZ         29.1    22.0   2876.7   587.8
# CA        452.4  1409.8  16321.2  6282.4

# %%
H7_Q1=pd.pivot_table(df_plant21,values="PNAME",index="PSTATABB",columns="PLFUELCT",aggfunc='count')

# %%
H7_Q1.head()
# Out:
# PLFUELCT       BIOMASS  COAL    GAS  GEOTHERMAL  HYDRO  NUCLEAR  OFSL   OIL  \
# PSTATABB
# AK        NaN      1.0   5.0   14.0         NaN   33.0      NaN   NaN  90.0
# AL        NaN     12.0   4.0   25.0         NaN   23.0      2.0   NaN   3.0
# AR        NaN      7.0   5.0   18.0         NaN   19.0      1.0   NaN   2.0
# AZ        NaN      3.0   4.0   28.0         NaN   11.0      1.0   NaN   2.0
# CA        1.0     98.0   1.0  337.0        32.0  254.0      1.0   NaN  14.0
#
# PLFUELCT  OTHF  SOLAR   WIND
# PSTATABB
# AK         4.0    NaN    4.0
# AL         NaN    7.0    NaN
# AR         NaN   15.0    NaN
# AZ         3.0   86.0    5.0
# CA        61.0  709.0  109.0

# %%
H7_Q2=pd.pivot_table(df_plant21,values="NAMEPCAP",index="PSTATABB",columns="PLFUELCT",aggfunc='sum')

# %%
H7_Q2.head()
# Out:
# PLFUELCT       BIOMASS    COAL      GAS  GEOTHERMAL    HYDRO  NUCLEAR  OFSL  \
# PSTATABB
# AK        NaN     11.5   210.9   1409.5         NaN    509.3      NaN   NaN
# AL        NaN    583.4  7429.3  13105.4         NaN   3318.3   5343.9   NaN
# AR        NaN    297.6  5487.0   7254.7         NaN   1350.9   1845.0   NaN
# AZ        NaN     33.4  3687.6  16649.0         NaN   2912.1   4209.6   NaN
# CA        2.2   1215.1    62.5  42048.4      2824.0  13810.7   2323.0   NaN
#
# PLFUELCT    OIL    OTHF    SOLAR    WIND
# PSTATABB
# AK        803.1    46.0      NaN    53.5
# AL         26.6     NaN    424.9     NaN
# AR          8.8     NaN    235.7     NaN
# AZ         29.1    22.0   2876.7   587.8
# CA        452.4  1409.8  16321.2  6282.4

# %%
H7_Q2=pd.pivot_table(df_plant21,values="NAMEPCAP",index="PSTATABB",columns="PLFUELCT",aggfunc='sum',fill_value="")

# %%
H7_Q2.head()
# Out:
# PLFUELCT      BIOMASS    COAL      GAS GEOTHERMAL    HYDRO NUCLEAR OFSL  \
# PSTATABB
# AK               11.5   210.9   1409.5               509.3
# AL              583.4  7429.3  13105.4              3318.3  5343.9
# AR              297.6  5487.0   7254.7              1350.9  1845.0
# AZ               33.4  3687.6  16649.0              2912.1  4209.6
# CA        2.2  1215.1    62.5  42048.4     2824.0  13810.7  2323.0
#
# PLFUELCT    OIL    OTHF    SOLAR    WIND
# PSTATABB
# AK        803.1    46.0             53.5
# AL         26.6            424.9
# AR          8.8            235.7
# AZ         29.1    22.0   2876.7   587.8
# CA        452.4  1409.8  16321.2  6282.4

# %%
H7_Q3_Step1=df_plant21=df_plant21[(df_plant21.PLFUELCT=="COAL")|(df_plant21.PLFUELCT=="GAS")|(df_plant21.PLFUELCT=="NUCLEAR")]

# %%
H7_Q3_Step2=pd.pivot_table(H7_Q3_Step1,index="PSTATABB",values="NAMEPCAP",columns="PLFUELCT",aggfunc='min',fill_value="")

# %%
H7_Q3_Step2
# Out:
# PLFUELCT    COAL    GAS NUCLEAR
# PSTATABB
# AK          20.0    7.8
# AL           3.8    3.4  1776.4
# AR         558.0    5.6  1845.0
# AZ         425.9    3.1  4209.6
# CA          62.5    0.9  2323.0
# CO         282.6    3.0
# CT                  0.4  2162.9
# DC                  4.6
# DE         464.1    1.3
# FL         471.0    4.1  2160.0
# GA        1956.8    1.4  1848.0
# HI         203.0
# IA           7.9    1.0
# ID                  5.6
# IL           5.1    1.0  1138.3
# IN          24.9    1.0
# KS         348.7    1.7  1267.7
# KY         344.0   18.0
# LA         720.7    3.4  1035.9
# MA                  1.5
# MD         229.0    2.1  1850.4
# ME                  3.8
# MI           2.5    1.3   811.8
# MN           5.0    3.7   685.0
# MO         261.0    4.3  1235.8
# MS         513.7    4.2  1440.0
# MT           1.5    4.0
# NC          32.0    6.6   950.9
# ND           6.0  293.1
# NE           5.0    1.5   801.0
# NH         496.4    5.0  1242.0
# ...

# %%
H7_Q3_Step3=pd.pivot_table(H7_Q3_Step1,index="PSTATABB",values="NAMEPCAP",columns="PLFUELCT",aggfunc=['min','max',np.mean,sum],fill_value="")

# %%
H7_Q3_Step3.head()
# Out:
#             min                  max                      mean              \
# PLFUELCT   COAL  GAS NUCLEAR    COAL     GAS NUCLEAR      COAL         GAS
# PSTATABB
# AK         20.0  7.8            92.8   346.9             42.18  100.678571
# AL          3.8  3.4  1776.4  2822.0  1995.7  3567.5  1857.325     524.216
# AR        558.0  5.6  1845.0  1800.0  2428.0  1845.0    1097.4  403.038889
# AZ        425.9  3.1  4209.6  1779.2  1857.0  4209.6     921.9  594.607143
# CA         62.5  0.9  2323.0    62.5  1798.0  2323.0      62.5    124.7727
#
#                       sum
# PLFUELCT  NUCLEAR    COAL      GAS NUCLEAR
# PSTATABB
# AK                  210.9   1409.5
# AL        2671.95  7429.3  13105.4  5343.9
# AR         1845.0  5487.0   7254.7  1845.0
# AZ         4209.6  3687.6  16649.0  4209.6
# CA         2323.0    62.5  42048.4  2323.0

# %%
H7_Q3_Step1.CAPFAC=pd.to_numeric(H7_Q3_Step1.CAPFAC)

# %%
H7_Q4=pd.pivot_table(H7_Q3_Step1,index="PSTATABB",values=["NAMEPCAP","CAPFAC"],columns="PLFUELCT",aggfunc=[np.mean],fill_value="")

# %%
H7_Q4.head()
# Out:
#               mean
#             CAPFAC                      NAMEPCAP
# PLFUELCT      COAL       GAS   NUCLEAR      COAL         GAS  NUCLEAR
# PSTATABB
# AK          0.4087  0.252297               42.18  100.678571
# AL        0.400292  0.400219  0.978255  1857.325     524.216  2671.95
# AR        0.513096  0.216083   0.83873    1097.4  403.038889   1845.0
# AZ        0.464065    0.2621   0.85773     921.9  594.607143   4209.6
# CA         0.55621  0.393974   0.80972      62.5    124.7727   2323.0

# %%
H7_Q5=pd.pivot_table(H7_Q3_Step1,index="PSTATABB",values=["NAMEPCAP","CAPFAC"],columns="PLFUELCT",aggfunc=[sum,np.mean],fill_value="")

# %%
H7_Q5.head()
# Out:
#               sum                                                    mean  \
#            CAPFAC                     NAMEPCAP                     CAPFAC
# PLFUELCT     COAL        GAS  NUCLEAR     COAL      GAS NUCLEAR      COAL
# PSTATABB
# AK         2.0435    3.27986             210.9   1409.5            0.4087
# AL        1.60117    9.60526  1.95651   7429.3  13105.4  5343.9  0.400292
# AR        2.56548    3.67341  0.83873   5487.0   7254.7  1845.0  0.513096
# AZ        1.85626     7.3388  0.85773   3687.6  16649.0  4209.6  0.464065
# CA        0.55621  128.04139  0.80972     62.5  42048.4  2323.0   0.55621
#
#
#                               NAMEPCAP
# PLFUELCT       GAS   NUCLEAR      COAL         GAS  NUCLEAR
# PSTATABB
# AK        0.252297               42.18  100.678571
# AL        0.400219  0.978255  1857.325     524.216  2671.95
# AR        0.216083   0.83873    1097.4  403.038889   1845.0
# AZ          0.2621   0.85773     921.9  594.607143   4209.6
# ...

# %%
H7_Q5=pd.pivot_table(H7_Q3_Step1,index="PSTATABB",values=["NAMEPCAP","CAPFAC"],columns="PLFUELCT",aggfunc={"NAMEPCAP":sum,"CAPFAC": np.mean},margins=True, fill_value="")

# %%
H7_Q5
# Out:
#             CAPFAC                                NAMEPCAP            \
# PLFUELCT      COAL       GAS   NUCLEAR       All      COAL       GAS
# PSTATABB
# AK          0.4087  0.252297            0.295742     210.9    1409.5
# AL        0.400292  0.400219  0.978255  0.438765    7429.3   13105.4
# AR        0.513096  0.216083   0.83873  0.307723    5487.0    7254.7
# AZ        0.464065    0.2621   0.85773   0.30463    3687.6   16649.0
# CA         0.55621  0.393974   0.80972  0.395741      62.5   42048.4
# CO        0.514868  0.144422            0.207927    5163.6    7432.5
# CT                  0.517206   0.90867  0.525535              6442.1
# DC                  0.706865            0.706865                22.9
# DE          0.0701   0.37222            0.342008     464.1    1955.6
# FL        0.394418  0.391199   0.75984  0.402278    9311.1   49398.4
# GA         0.21352   0.23648  0.902275  0.272558    9019.4   18779.0
# HI         0.62254                       0.62254     203.0
# ...

# %% [markdown]
# Merge, shape - see more on Lab 4

# %%
##Merging data frames
df_gen21=pd.read_excel(io="eGRID2021_data.xlsx",sheet_name="GEN21",skiprows=1,keep_default_na=False)

# %%
df_gen21_sub=df_gen21.loc[:,["ORISPL","GENYRONL","GENSTAT"]]

# %%
df_gen21_sub.shape
# Out:
# (25031, 3)

# %%
df_plant21_sub=df_plant21.loc[:,["ORISPL","PLPRMFL","NAMEPCAP","CAPFAC"]]

# %%
df_plant21_sub.shape
# Out:
# (2259, 4)

# %%
merged_inner=pd.merge(df_plant21_sub,df_gen21_sub)

# %%
merged_inner.head()
# Out:
#    ORISPL PLPRMFL  NAMEPCAP  CAPFAC GENYRONL GENSTAT
# 0   54452      NG      12.5     NaN     1977      OS
# 1   54452      NG      12.5     NaN     1977      OS
# 2   54452      NG      12.5     NaN     1977      OS
# 3   54452      NG      12.5     NaN     1977      OS
# 4   54452      NG      12.5     NaN     1977      OS
